# %%
import pandas as pd
import nltk
from nltk.corpus import brown
from nltk import FreqDist
from nltk.corpus import stopwords
import numpy as np

# %%
kw = pd.read_csv("./Keyword Stats 2020-05-13 at 22_32_03 - Keyword Stats 2020-05-13 at 22_32_03.csv")

# %%
kw.head(10)
# Out:
#              Keyword Currency Avg. monthly searches Min search volume  \
# 0               ikea      EUR                   N/D         1.000.000
# 1        ikea online      EUR                   N/D                10
# 2        ikea kallax      EUR                   N/D                 1
# 3        ikea family      EUR                   N/D                10
# 4         ikea besta      EUR                   N/D                 1
# 5        kallax ikea      EUR                   N/D                10
# 6         ikea sofas      EUR                   N/D                10
# 7  ikea black friday      EUR                   N/D                 1
# 8      armarios ikea      EUR                   N/D               100
# 9       ikea trofast      EUR                   N/D                 1
#
#   Max search volume Competition  Competition (indexed value)  \
# 0        10.000.000        Baja                          2.0
# 1               100       Media                         47.0
# 2                10        Baja                         25.0
# 3               100        Baja                          4.0
# 4                10       Media                         40.0
# 5               100        Baja                         31.0
# 6               100        Alta                        100.0
# 7                10        Baja                         27.0
# 8         1.000.000        Alta                        100.0
# 9                10        Baja                          3.0
#
#   Top of page bid (low range) Top of page bid (high range)  \
# 0                        0,04                         0,20
# 1                        0,04                         0,71
# 2                        0,04                         0,20
# 3                        0,04                         0,49
# 4                        0,04                         0,30
# 5                        0,04                         0,20
# 6                        0,04                         0,12
# 7                         NaN                          NaN
# 8                        0,04                         0,14
# 9                         NaN                          NaN
#
#    Ad impression share  ...  Searches: Dec 2019  Searches: Jan 2020  \
# 0                  NaN  ...                 NaN                 NaN
# 1                  NaN  ...                 NaN                 NaN
# 2                  NaN  ...                 NaN                 NaN
# 3                  NaN  ...                 NaN                 NaN
# 4                  NaN  ...                 NaN                 NaN
# 5                  NaN  ...                 NaN                 NaN
# 6                  NaN  ...                 NaN                 NaN
# 7                  NaN  ...                 NaN                 NaN
# 8                  NaN  ...                 NaN                 NaN
# 9                  NaN  ...                 NaN                 NaN
#
#    Searches: Feb 2020  Searches: Mar 2020  Searches: Apr 2020  Concept: Otros  \
# 0                 NaN                 NaN                 NaN             NaN
# 1                 NaN                 NaN                 NaN             NaN
# 2                 NaN                 NaN                 NaN             NaN
# 3                 NaN                 NaN                 NaN             NaN
# 4                 NaN                 NaN                 NaN             NaN
# 5                 NaN                 NaN                 NaN             NaN
# 6                 NaN                 NaN                 NaN             NaN
# 7                 NaN                 NaN                 NaN             NaN
# 8                 NaN                 NaN                 NaN             NaN
# 9                 NaN                 NaN                 NaN             NaN
#
#    Concept: Mueble  Concept: Otras Marcas  Concept:  \
# 0              NaN                    NaN       NaN
# 1              NaN                    NaN       NaN
# 2              NaN                    NaN       NaN
# 3              NaN            ikea family       NaN
# 4              NaN                    NaN       NaN
# 5              NaN                    NaN       NaN
# 6             sofa                    NaN       NaN
# 7              NaN                    NaN       NaN
# 8              NaN                    NaN       NaN
# 9              NaN                    NaN       NaN
#
#    Concept: Institución Financiera
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
#
# [10 rows x 31 columns]

# %%
kw.columns
# Out:
# Index(['Keyword', 'Currency', 'Avg. monthly searches', 'Min search volume',
#        'Max search volume', 'Competition', 'Competition (indexed value)',
#        'Top of page bid (low range)', 'Top of page bid (high range)',
#        'Ad impression share', 'Organic impression share',
#        'Organic average position', 'In account?', 'In plan?',
#        'Searches: May 2019', 'Searches: Jun 2019', 'Searches: Jul 2019',
#        'Searches: Aug 2019', 'Searches: Sep 2019', 'Searches: Oct 2019',
#        'Searches: Nov 2019', 'Searches: Dec 2019', 'Searches: Jan 2020',
#        'Searches: Feb 2020', 'Searches: Mar 2020', 'Searches: Apr 2020',
#        'Concept: Otros', 'Concept: Mueble', 'Concept: Otras Marcas',
#        'Concept:', 'Concept: Institución Financiera'],
#       dtype='object')

# %%
kw.drop(kw.columns.difference(['Keyword','Max search volume','Competition (indexed value)','Top of page bid (low range)','Top of page bid (high range)']), 1, inplace=True)

# %%
kw.head(10)
# Out:
#              Keyword Max search volume  Competition (indexed value)  \
# 0               ikea        10.000.000                          2.0
# 1        ikea online               100                         47.0
# 2        ikea kallax                10                         25.0
# 3        ikea family               100                          4.0
# 4         ikea besta                10                         40.0
# 5        kallax ikea               100                         31.0
# 6         ikea sofas               100                        100.0
# 7  ikea black friday                10                         27.0
# 8      armarios ikea         1.000.000                        100.0
# 9       ikea trofast                10                          3.0
#
#   Top of page bid (low range) Top of page bid (high range)
# 0                        0,04                         0,20
# 1                        0,04                         0,71
# 2                        0,04                         0,20
# 3                        0,04                         0,49
# 4                        0,04                         0,30
# 5                        0,04                         0,20
# 6                        0,04                         0,12
# 7                         NaN                          NaN
# 8                        0,04                         0,14
# 9                         NaN                          NaN

# %%
kw.shape
# Out:
# (1435, 5)

# %%
kw['Keyword'] = kw['Keyword'].apply(lambda tokenize: nltk.word_tokenize(tokenize))

# %%
kw.head(10)
# Out:
#                  Keyword Max search volume  Competition (indexed value)  \
# 0                 [ikea]        10.000.000                          2.0
# 1         [ikea, online]               100                         47.0
# 2         [ikea, kallax]                10                         25.0
# 3         [ikea, family]               100                          4.0
# 4          [ikea, besta]                10                         40.0
# 5         [kallax, ikea]               100                         31.0
# 6          [ikea, sofas]               100                        100.0
# 7  [ikea, black, friday]                10                         27.0
# 8       [armarios, ikea]         1.000.000                        100.0
# 9        [ikea, trofast]                10                          3.0
#
#   Top of page bid (low range) Top of page bid (high range)
# 0                        0,04                         0,20
# 1                        0,04                         0,71
# 2                        0,04                         0,20
# 3                        0,04                         0,49
# 4                        0,04                         0,30
# 5                        0,04                         0,20
# 6                        0,04                         0,12
# 7                         NaN                          NaN
# 8                        0,04                         0,14
# 9                         NaN                          NaN

# %%
stop = stopwords.words('spanish')
kw['Keyword'] = kw['Keyword'].apply(lambda keyword: [word for word in keyword if word not in stop])

# %%
kw.head(10)
# Out:
#                  Keyword Max search volume  Competition (indexed value)  \
# 0                 [ikea]        10.000.000                          2.0
# 1         [ikea, online]               100                         47.0
# 2         [ikea, kallax]                10                         25.0
# 3         [ikea, family]               100                          4.0
# 4          [ikea, besta]                10                         40.0
# 5         [kallax, ikea]               100                         31.0
# 6          [ikea, sofas]               100                        100.0
# 7  [ikea, black, friday]                10                         27.0
# 8       [armarios, ikea]         1.000.000                        100.0
# 9        [ikea, trofast]                10                          3.0
#
#   Top of page bid (low range) Top of page bid (high range)
# 0                        0,04                         0,20
# 1                        0,04                         0,71
# 2                        0,04                         0,20
# 3                        0,04                         0,49
# 4                        0,04                         0,30
# 5                        0,04                         0,20
# 6                        0,04                         0,12
# 7                         NaN                          NaN
# 8                        0,04                         0,14
# 9                         NaN                          NaN

# %%
freq = pd.Series(' '.join(" ".join(word) for word in kw['Keyword']).split(" ")).value_counts()[:10]
freq
# Out:
# ikea         1203
# cama           27
# mesas          24
# sillas         20
# muebles        20
# camas          17
# armarios       17
# sofa           12
# colchones       9
# 2019            9
# dtype: int64

# %%
#fdist = FreqDist(kw.Keyword)
#fdist

# %%
kw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Keyword                       1435 non-null   object
#  1   Max search volume             1435 non-null   object
#  2   Competition (indexed value)   1420 non-null   float64
#  3   Top of page bid (low range)   296 non-null    object
#  4   Top of page bid (high range)  296 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 56.2+ KB

# %%
kw['Keyword']=kw['Keyword'].apply(', '.join)

# %%
cat_1 = input()
# Out:
# ikea

# %%
cell_cat_1 = input()
# Out:
# Brand

# %%
kw['Cat_1']= np.where(kw['Keyword'].str.contains(cat_1,regex=True),cell_cat_1,'No Brand')

# %%
kw.head(500)
# Out:
#           Keyword Max search volume  Competition (indexed value)  \
# 0            ikea        10.000.000                          2.0
# 1    ikea, online               100                         47.0
# 2    ikea, kallax                10                         25.0
# 3    ikea, family               100                          4.0
# 4     ikea, besta                10                         40.0
# ..            ...               ...                          ...
# 495  frakta, ikea               100                          1.0
# 496  koppla, ikea               100                          0.0
# 497   istad, ikea               100                          1.0
# 498      björksta               100                          1.0
# 499   pello, ikea                 1                         50.0
#
#     Top of page bid (low range) Top of page bid (high range)     Cat_1
# 0                          0,04                         0,20     Brand
# 1                          0,04                         0,71     Brand
# 2                          0,04                         0,20     Brand
# 3                          0,04                         0,49     Brand
# 4                          0,04                         0,30     Brand
# ..                          ...                          ...       ...
# 495                         NaN                          NaN     Brand
# 496                         NaN                          NaN     Brand
# 497                         NaN                          NaN     Brand
# 498                         NaN                          NaN  No Brand
# 499                         NaN                          NaN     Brand
#
# [500 rows x 6 columns]

# %%
cat = pd.read_csv("./keyword - Sheet1.csv")
cat.head(20)
# Out:
#      Keyword         Cat
# 0       sofa       SALÓN
# 1     sillon       SALÓN
# 2    armario  MOBILIARIO
# 3     cómoda  DORMITORIO
# 4       cama  DORMITORIO
# 5   almohada  DORMITORIO
# 6      silla  MOBILIARIO
# 7    sillita  MOBILIARIO
# 8    colchon  DORMITORIO
# 9       mesa  MOBILIARIO
# 10    cuadro  DECORACIÓN
# 11  taburete  MOBILIARIO
# 12     fejka     FAMILIA
# 13     besta     FAMILIA
# 14      ikea       Brand

# %%
results = pd.merge(kw,cat,on='Keyword',how='left')
results.head(500)
# Out:
#           Keyword Max search volume  Competition (indexed value)  \
# 0            ikea        10.000.000                          2.0
# 1    ikea, online               100                         47.0
# 2    ikea, kallax                10                         25.0
# 3    ikea, family               100                          4.0
# 4     ikea, besta                10                         40.0
# ..            ...               ...                          ...
# 495  frakta, ikea               100                          1.0
# 496  koppla, ikea               100                          0.0
# 497   istad, ikea               100                          1.0
# 498      björksta               100                          1.0
# 499   pello, ikea                 1                         50.0
#
#     Top of page bid (low range) Top of page bid (high range)     Cat_1  Cat
# 0                          0,04                         0,20     Brand  NaN
# 1                          0,04                         0,71     Brand  NaN
# 2                          0,04                         0,20     Brand  NaN
# 3                          0,04                         0,49     Brand  NaN
# 4                          0,04                         0,30     Brand  NaN
# ..                          ...                          ...       ...  ...
# 495                         NaN                          NaN     Brand  NaN
# 496                         NaN                          NaN     Brand  NaN
# 497                         NaN                          NaN     Brand  NaN
# 498                         NaN                          NaN  No Brand  NaN
# 499                         NaN                          NaN     Brand  NaN
#
# [500 rows x 7 columns]

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1435 entries, 0 to 1434
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Keyword                       1435 non-null   object
#  1   Max search volume             1435 non-null   object
#  2   Competition (indexed value)   1420 non-null   float64
#  3   Top of page bid (low range)   296 non-null    object
#  4   Top of page bid (high range)  296 non-null    object
#  5   Cat_1                         1435 non-null   object
#  6   Cat                           1 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 89.7+ KB

# %%
new_result= kw.assign(cat= kw['Keyword'].map(cat.set_index('Keyword')['Cat']))

# %%
new_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Keyword                       1435 non-null   object
#  1   Max search volume             1435 non-null   object
#  2   Competition (indexed value)   1420 non-null   float64
#  3   Top of page bid (low range)   296 non-null    object
#  4   Top of page bid (high range)  296 non-null    object
#  5   Cat_1                         1435 non-null   object
#  6   cat                           7 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 78.6+ KB

# %%
new_result.head(200)
# Out:
#             Keyword Max search volume  Competition (indexed value)  \
# 0              ikea        10.000.000                          2.0
# 1      ikea, online               100                         47.0
# 2      ikea, kallax                10                         25.0
# 3      ikea, family               100                          4.0
# 4       ikea, besta                10                         40.0
# ..              ...               ...                          ...
# 195  ekedalen, ikea                 1                         23.0
# 196           fejka                 1                         11.0
# 197   ikea, lixhult                 1                          3.0
# 198    norden, ikea                 1                         23.0
# 199         lixhult                 1                          9.0
#
#     Top of page bid (low range) Top of page bid (high range)     Cat_1  \
# 0                          0,04                         0,20     Brand
# 1                          0,04                         0,71     Brand
# 2                          0,04                         0,20     Brand
# 3                          0,04                         0,49     Brand
# 4                          0,04                         0,30     Brand
# ..                          ...                          ...       ...
# 195                         NaN                          NaN     Brand
# 196                         NaN                          NaN  No Brand
# 197                         NaN                          NaN     Brand
# 198                         NaN                          NaN     Brand
# 199                        1,09                         1,74  No Brand
#
#          cat
# 0      Brand
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 195      NaN
# 196  FAMILIA
# 197      NaN
# 198      NaN
# 199      NaN
#
# [200 rows x 7 columns]

# %%
kw['Cat_2']= np.where(kw['Keyword'].str.contains(cat['Keyword'],regex=True),cat['Cat'],'-')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-116164d107b3> in <module>
# ----> 1 kw['Cat_2']= np.where(kw['Keyword'].str.contains(cat['Keyword'],regex=True),cat['Cat'],'-')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/strings.py in wrapper(self, *args, **kwargs)
#    1950                 )
#    1951                 raise TypeError(msg)
# -> 1952             return func(self, *args, **kwargs)
#    1953
#    1954         wrapper.__name__ = func_name
#
# ~/.local/lib/python3.6/site-packages/pandas/core/strings.py in contains(self, pat, case, flags, na, regex)
#    2759     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
#    2760         result = str_contains(
# -> 2761             self._parent, pat, case=case, flags=flags, na=na, regex=regex
#    2762         )
#    2763         return self._wrap_result(result, fill_value=na, returns_string=False)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/strings.py in str_contains(arr, pat, case, flags, na, regex)
#     439             flags |= re.IGNORECASE
#     440
# --> 441         regex = re.compile(pat, flags=flags)
#     442
#     443         if regex.groups > 0:
#
# /usr/lib/python3.6/re.py in compile(pattern, flags)
#     231 def compile(pattern, flags=0):
#     232     "Compile a regular expression pattern, returning a pattern object."
# --> 233     return _compile(pattern, flags)
#     234
#     235 def purge():
#
# /usr/lib/python3.6/re.py in _compile(pattern, flags)
#     287     # internal: compile pattern
#     288     try:
# --> 289         p, loc = _cache[type(pattern), pattern, flags]
#     290         if loc is None or loc == _locale.setlocale(_locale.LC_CTYPE):
#     291             return p
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __hash__(self)
#    1796     def __hash__(self):
#    1797         raise TypeError(
# -> 1798             f"{repr(type(self).__name__)} objects are mutable, "
#    1799             f"thus they cannot be hashed"
#    1800         )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
