# %%
import pandas as pd
import nltk
from nltk.corpus import brown
from nltk import FreqDist

# %%
kw = pd.read_csv("./Keyword Stats 2020-05-13 at 22_32_03 - Keyword Stats 2020-05-13 at 22_32_03.csv")

# %%
kw.head(100)
# Out:
#           Keyword Currency Avg. monthly searches Min search volume  \
# 0            ikea      EUR                   N/D         1.000.000
# 1     ikea online      EUR                   N/D                10
# 2     ikea kallax      EUR                   N/D                 1
# 3     ikea family      EUR                   N/D                10
# 4      ikea besta      EUR                   N/D                 1
# ..            ...      ...                   ...               ...
# 95  ikea la gavia      EUR                   N/D                 1
# 96     ikea mulig      EUR                   N/D               100
# 97  ikea grundtal      EUR                   N/D               100
# 98      ikea 2019      EUR                   N/D               100
# 99    ikea hektar      EUR                   N/D                10
#
#    Max search volume Competition  Competition (indexed value)  \
# 0         10.000.000        Baja                          2.0
# 1                100       Media                         47.0
# 2                 10        Baja                         25.0
# 3                100        Baja                          4.0
# 4                 10       Media                         40.0
# ..               ...         ...                          ...
# 95                10        Baja                          4.0
# 96                 1        Baja                         31.0
# 97                 1        Baja                          1.0
# 98                 1        Alta                         82.0
# 99               100        Baja                          2.0
#
#    Top of page bid (low range) Top of page bid (high range)  \
# 0                         0,04                         0,20
# 1                         0,04                         0,71
# 2                         0,04                         0,20
# 3                         0,04                         0,49
# 4                         0,04                         0,30
# ..                         ...                          ...
# 95                        0,03                         0,30
# 96                         NaN                          NaN
# 97                         NaN                          NaN
# 98                         NaN                          NaN
# 99                         NaN                          NaN
#
#     Ad impression share  ...  Searches: Dec 2019  Searches: Jan 2020  \
# 0                   NaN  ...                 NaN                 NaN
# 1                   NaN  ...                 NaN                 NaN
# 2                   NaN  ...                 NaN                 NaN
# 3                   NaN  ...                 NaN                 NaN
# 4                   NaN  ...                 NaN                 NaN
# ..                  ...  ...                 ...                 ...
# 95                  NaN  ...                 NaN                 NaN
# 96                  NaN  ...                 NaN                 NaN
# 97                  NaN  ...                 NaN                 NaN
# 98                  NaN  ...                 NaN                 NaN
# 99                  NaN  ...                 NaN                 NaN
#
#     Searches: Feb 2020  Searches: Mar 2020  Searches: Apr 2020  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# ..                 ...                 ...                 ...
# 95                 NaN                 NaN                 NaN
# 96                 NaN                 NaN                 NaN
# 97                 NaN                 NaN                 NaN
# 98                 NaN                 NaN                 NaN
# 99                 NaN                 NaN                 NaN
#
#     Concept: Otros  Concept: Mueble  Concept: Otras Marcas  Concept:  \
# 0              NaN              NaN                    NaN       NaN
# 1              NaN              NaN                    NaN       NaN
# 2              NaN              NaN                    NaN       NaN
# 3              NaN              NaN            ikea family       NaN
# 4              NaN              NaN                    NaN       NaN
# ..             ...              ...                    ...       ...
# 95             NaN              NaN                  gavia       NaN
# 96             NaN              NaN                    NaN       NaN
# 97             NaN              NaN                    NaN       NaN
# 98             NaN              NaN                    NaN       NaN
# 99             NaN              NaN                    NaN       NaN
#
#     Concept: Institución Financiera
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 95                              NaN
# 96                              NaN
# 97                              NaN
# 98                              NaN
# 99                              NaN
#
# [100 rows x 31 columns]

# %%
kw.columns
# Out:
# Index(['Keyword', 'Currency', 'Avg. monthly searches', 'Min search volume',
#        'Max search volume', 'Competition', 'Competition (indexed value)',
#        'Top of page bid (low range)', 'Top of page bid (high range)',
#        'Ad impression share', 'Organic impression share',
#        'Organic average position', 'In account?', 'In plan?',
#        'Searches: May 2019', 'Searches: Jun 2019', 'Searches: Jul 2019',
#        'Searches: Aug 2019', 'Searches: Sep 2019', 'Searches: Oct 2019',
#        'Searches: Nov 2019', 'Searches: Dec 2019', 'Searches: Jan 2020',
#        'Searches: Feb 2020', 'Searches: Mar 2020', 'Searches: Apr 2020',
#        'Concept: Otros', 'Concept: Mueble', 'Concept: Otras Marcas',
#        'Concept:', 'Concept: Institución Financiera'],
#       dtype='object')

# %%
kw.drop(kw.columns.difference(['Keyword','Max search volume','Competition (indexed value)','Top of page bid (low range)','Top of page bid (high range)']), 1, inplace=True)

# %%
kw.head(100)
# Out:
#           Keyword Max search volume  Competition (indexed value)  \
# 0            ikea        10.000.000                          2.0
# 1     ikea online               100                         47.0
# 2     ikea kallax                10                         25.0
# 3     ikea family               100                          4.0
# 4      ikea besta                10                         40.0
# ..            ...               ...                          ...
# 95  ikea la gavia                10                          4.0
# 96     ikea mulig                 1                         31.0
# 97  ikea grundtal                 1                          1.0
# 98      ikea 2019                 1                         82.0
# 99    ikea hektar               100                          2.0
#
#    Top of page bid (low range) Top of page bid (high range)
# 0                         0,04                         0,20
# 1                         0,04                         0,71
# 2                         0,04                         0,20
# 3                         0,04                         0,49
# 4                         0,04                         0,30
# ..                         ...                          ...
# 95                        0,03                         0,30
# 96                         NaN                          NaN
# 97                         NaN                          NaN
# 98                         NaN                          NaN
# 99                         NaN                          NaN
#
# [100 rows x 5 columns]

# %%
kw.shape
# Out:
# (1435, 5)

# %%
kw['Keyword'] = kw['Keyword'].apply(lambda tokenize: nltk.word_tokenize(tokenize))

# %%
kw.head(100)
# Out:
#               Keyword Max search volume  Competition (indexed value)  \
# 0              [ikea]        10.000.000                          2.0
# 1      [ikea, online]               100                         47.0
# 2      [ikea, kallax]                10                         25.0
# 3      [ikea, family]               100                          4.0
# 4       [ikea, besta]                10                         40.0
# ..                ...               ...                          ...
# 95  [ikea, la, gavia]                10                          4.0
# 96      [ikea, mulig]                 1                         31.0
# 97   [ikea, grundtal]                 1                          1.0
# 98       [ikea, 2019]                 1                         82.0
# 99     [ikea, hektar]               100                          2.0
#
#    Top of page bid (low range) Top of page bid (high range)
# 0                         0,04                         0,20
# 1                         0,04                         0,71
# 2                         0,04                         0,20
# 3                         0,04                         0,49
# 4                         0,04                         0,30
# ..                         ...                          ...
# 95                        0,03                         0,30
# 96                         NaN                          NaN
# 97                         NaN                          NaN
# 98                         NaN                          NaN
# 99                         NaN                          NaN
#
# [100 rows x 5 columns]

# %%
#fdist = FreqDist(kw.Keyword)
#fdist

# %%
kw.Keyword.value_counts()
